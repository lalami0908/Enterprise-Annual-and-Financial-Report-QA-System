# %%
import cx_Oracle
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
import os
import time

# %%
#上市公司

Listed_url = 'https://isin.twse.com.tw/isin/C_public.jsp?strMode=2'
res = requests.get(Public_url)
soup = BeautifulSoup(res.text)
table = soup.find('table',{'class':'h4'})

output_rows = []
for table_row in table.findAll('tr'):
    columns = table_row.findAll('td')
    output_row = []
    for column in columns:
        output_row.append(column.text)
    output_rows.append(output_row)
    
with open('output.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(output_rows)

# %%
#OTC
    
OTC_url = 'https://isin.twse.com.tw/isin/C_public.jsp?strMode=4'
res = requests.get(OTC_url)
soup = BeautifulSoup(res.text)
table = soup.find('table',{'class':'h4'})

output_rows = []
for table_row in table.findAll('tr'):
    columns = table_row.findAll('td')
    output_row = []
    for column in columns:
        output_row.append(column.text)
    output_rows.append(output_row)
    
with open('OTC.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(output_rows)

# %%
#興櫃公司
    
Emerging_url = 'https://isin.twse.com.tw/isin/C_public.jsp?strMode=5'
res = requests.get(Emerging_url)
soup = BeautifulSoup(res.text)
table = soup.find('table',{'class':'h4'})

output_rows = []
for table_row in table.findAll('tr'):
    columns = table_row.findAll('td')
    output_row = []
    for column in columns:
        output_row.append(column.text)
    output_rows.append(output_row)
    
with open('Emerging.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(output_rows)

# %%
#公開發行等
    
Public_url = 'https://isin.twse.com.tw/isin/C_public.jsp?strMode=1'
res = requests.get(Public_url)
soup = BeautifulSoup(res.text)
table = soup.find('table',{'class':'h4'})

output_rows = []
for table_row in table.findAll('tr'):
    columns = table_row.findAll('td')
    output_row = []
    for column in columns:
        output_row.append(column.text)
    output_rows.append(output_row)
    
with open('Public.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(output_rows)

# %%
df = pd.read_excel('所有公司代號一覽表.xlsx', sheet_name = '上市')
df['id']
# Out:
# 0          1101
# 1          1102
# 2          1103
# 3          1104
# 4          1108
#           ...
# 17291    01003T
# 17292    01004T
# 17293    01007T
# 17294    01009T
# 17295    01010T
# Name: id, Length: 17296, dtype: object

# %%
for id in df['id']:
    print(id)
# Out:
# 1101
# 1102
# 1103
# 1104
# 1108
# 1109
# 1110
# 1201
# 1203
# 1210
# 1213
# 1215
# 1216
# 1217
# 1218
# 1219
# 1220
# 1225
# 1227
# 1229
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# 1256
# 1301
# 1303
# 1304
# 1305
# 1307
# 1308
# 1309
# 1310
# 1312
# 1313
# 1314
# 1315
# 1316
# 1319
# 1321
# 1323
# 1324
# 1325
# 1326
# 1337
# 1338
# 1339
# 1340
# 1341
# 1402
# 1409
# 1410
# 1413
# 1414
# 1416
# 1417
# 1418
# 1419
# 1423
# 1432
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# 1446
# 1447
# 1449
# 1451
# 1452
# 1453
# 1454
# 1455
# 1456
# 1457
# 1459
# 1460
# 1463
# 1464
# 1465
# 1466
# 1467
# 1468
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1503
# 1504
# 1506
# 1507
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1519
# 1521
# 1522
# 1524
# 1525
# 1526
# 1527
# 1528
# 1529
# 1530
# 1531
# 1532
# 1533
# 1535
# 1536
# 1537
# 1538
# 1539
# 1540
# 1541
# 1558
# 1560
# 1568
# 1582
# 1583
# 1587
# 1589
# 1590
# 1592
# 1598
# 1603
# 1604
# ...

# %%
NO_url='https://doc.twse.com.tw/server-java/t57sb01?step=1&colorchg=1&co_id=058447&year=103&mtype=F&'
res=requests.get(NO_url)
soup=BeautifulSoup(res.text)
result = soup.find('h4')
if result:
    if result.text == "查無所需資料":
        print(result.text)
# Out:
# 查無所需資料

# %%
for year in range(99,109):
Report_url='https://doc.twse.com.tw/server-java/t57sb01?step=1&colorchg=1&co_id=2002&year=107&mtype=F&'
res=requests.get(Report_url)
soup=BeautifulSoup(res.text)
#print soup

#step1
Bos_Basic=soup.findAll('table',{'border':'5'})[0]
print(Bos_Basic)
# Out:
# <table align="center" bgcolor="#ffffff" border="5" bordercolor="#ff6600">
# <tr><th>證券代號</th><th>資料年度</th><th>資料類型</th><th>結案類型</th><th>股東會性質</th><th>資料細節說明</th><th>備註</th><th>電子檔案</th><th>檔案大小</th><th>上傳日期</th></tr>
# <tr>
# <td align="center">2002</td><td align="center">107 年</td>
# <td align="center">股東會相關資料</td>
# <td align="center"> </td>
# <td align="center">常會</td>
# <td align="center">開會通知</td><td align="center"> </td><td><a href='javascript:readfile2("F","2002","2018_2002_20180621F01.pdf");'>2018_2002_20180621F01.pdf</a></td><td align="right">              1,274,440</td>
# <td align="cetern">107/05/21 13:59:27</td>
# </tr>
# <tr>
# <td align="center">2002</td><td align="center">106 年</td>
# <td align="center">股東會相關資料</td>
# <td align="center"> </td>
# <td align="center">常會</td>
# ...

# %%
#step2
steel105_data=[]
Play_stat_row=Bos_Basic.findAll('tr')
len(Play_stat_row)
# Out:
# 11

# %%
for i in range(0,len(Play_stat_row)):
    if i==0:
        pass
    else:
        print(Play_stat_row[i].text)
# Out:
# 2002107 年
# 股東會相關資料
#
# 常會
# 開會通知 2018_2002_20180621F01.pdf              1,274,440
# 107/05/21 13:59:27
#
#
# 2002106 年
# 股東會相關資料
#
# 常會
# 股東會年報 2017_2002_20180621F04.pdf              5,827,121
# 107/05/21 14:02:53
#
#
# 2002107 年
# 股東會相關資料
#
# 常會
# 議事手冊及會議補充資料 2018_2002_20180621F02.pdf              5,235,594
# 107/05/21 14:06:28
#
#
# 2002107 年
# 股東會相關資料
#
# 常會
# 股東會各項議案參考資料 2018_2002_20180621F13.pdf              5,235,594
# 107/05/21 14:12:39
#
#
# 2002107 年
# 股東會相關資料
#
# 常會
# 年報前十大股東相互間關係表 2018_2002_20180621F17.pdf                 65,507
# 107/05/21 14:16:06
#
#
# 2002107 年
# 股東會相關資料
#
# 常會
# 英文版-開會通知 2018_2002_20180621FE1.pdf                  8,506
# 107/05/21 14:18:28
#
#
# 2002107 年
# 股東會相關資料
#
# 常會
# 英文版-會議議事手冊 2018_2002_20180621FE2.pdf              1,222,941
# 107/05/21 14:20:41
#
#
# 2002106 年
# 股東會相關資料
#
# 常會
# 英文版-股東會年報 2017_2002_20180621FE4.pdf             10,230,416
# 107/05/30 14:04:18
#
#
# 2002107 年
# 股東會相關資料
#
# 常會
# ...

# %%
#step3
data=[]
for i in range(0,len(Play_stat_row)):
    Doc = Bos_Basic.findAll('tr')[i].findAll('td')
    for j in range(0,len(Doc)):
        if (Doc[j].find(text="股東會年報")):
            data.append(Doc[j+2].text)

# %%
data[0]
# Out:
# '2017_2002_20180621F04.pdf'

# %%
firstname = str(data[0])
firstname
# Out:
# '2017_2002_20180621F04.pdf'

# %%
inform = firstname.split('_')
year = inform[0]
company_id = inform[1]
comapny_id
# Out:
# '2002'

# %%
####js參考####
javascript:readfile2("F","2002","2016_2002_20160623F01.pdf");
function readfile(kind,coid,filename)
{
	var f = document.forms[0];
	f.step.value = 9;
	f.kind.value = kind;
	f.co_id.value = coid;
	f.filename.value = filename;
	f.submit();
}

# %%
url = 'https://doc.twse.com.tw/server-java/t57sb01'
#captcha = input()
params = {
    'step': '9',
    'kind': 'F',
    'co_id': comapny_id,
    'filename': str(data[0]),
}
html = requests.post(url, params)
html.encoding = html.apparent_encoding
print(html.text)
# Out:
# <html><head><title>電子資料查詢作業</title></head><body background='/image/t57sf13.jpg'>
# <center>
# <h2><font color="blue">電子資料查詢作業</font></h2>
# <span id='wait'>請稍候......</span>
# <script>window.wait.style.display='none';</script>
# 電子檔案：<a href='/pdf/2017_2002_20180621F04_20200705_163633.pdf'>2017_2002_20180621F04.pdf</a>
# <p>
# 請點選連結直接開啟或按右鍵另存新檔
# <script>window.focus();</script>

# %%
result = BeautifulSoup(html.text)
file_name = result.findAll('a')
fileURL = file_name[0].get('href')
fileURL
# Out:
# '/pdf/2017_2002_20180621F04_20200705_163633.pdf'

# %%
url = 'https://doc.twse.com.tw'+fileURL
r = requests.get(url)
pdf = r.content       #響應的二進位制檔案
with open(str(data[0])+'.pdf','wb') as f:     #二進位制寫入
    f.write(pdf)

# %%
for id in df['id']: 
    if id == "1101":
        print(id)
# Out:
# 1101

# %%
cnt = 0
Lack = {}
Other = {}

# %%
#cnt = 0
#Lack = {}
#Other = {}

for id in df['id']: 
    if int(id) < 1589:
        continue
    
    print("================="+str(id)+"=================")
    for year in range(99,110):
        cnt += 1
        
        if cnt%2 == 0:
            print(".....zZzzz.....sleep")
            time.sleep(10)
        else:
            print(".....zZzzz.....sleep")
            time.sleep(10)
        
        if year == 105:
        #or cnt%5 == 0
            print(".....zZzzz.....sleep")
            time.sleep(10)
            
        print("---------"+str(year)+"---------")
        Report_url='https://doc.twse.com.tw/server-java/t57sb01?step=1&colorchg=1&co_id='+str(id)+'&year='+str(year)+'&mtype=F&'
        res=requests.get(Report_url)
        soup=BeautifulSoup(res.text)
        #print soup

        #step0 驗證有沒有結果
        result = soup.find('h4')
        if result:
            if result.text == "查無所需資料":
                print(result.text)
                continue

        #step1 抓表格
        Bos_Basic=soup.find('table',{'border':'5'})
        if(Bos_Basic):
            data=[]
        else:
            print("**********NO TABLE**********")
            if id in Lack:
                Lack[id] += 1
            else:
                Lack[id] = 1
            continue

        #step2 抓表格內容
        Play_stat_row = Bos_Basic.findAll('tr')

        #step3 找到年報位置
        data=[]
        for i in range(0,len(Play_stat_row)):
            Doc = Play_stat_row[i].findAll('td')
            for j in range(0,len(Doc)):
                if (Doc[j].find(text="股東會年報")):
                    data.append(Doc[j+2].text)
        if(len(data)==0):
            print("沒有年報")
            continue

        #step4 分割檔名
        firstname = str(data[0])
        inform = firstname.split('_')
        adyear = inform[0]
        company_id = inform[1]
        typ = firstname.split('.')

        #step5 傳送表單要求
        url = 'https://doc.twse.com.tw/server-java/t57sb01'
        params = {
            'step': '9',
            'kind': 'F',
            'co_id': company_id,
            'filename': str(data[0]),
        }
        
        #step6 檔案類型判斷
        #非pdf
        if typ[1] != "pdf":
            print(firstname)
            if id in Other:
                Other[id] += 1
            else:
                Other[id] = 1
                
            des_path = "./上市/"+company_id
            if not os.path.isdir(des_path):  #如果資料夾不存在就建立
                os.mkdir(des_path)
            
            r = requests.post(url, params)
            file = r.content       #響應的二進位制檔案
            with open(des_path+'/'+str(data[0]),'wb') as f:     #二進位制寫入
                f.write(file)

        #pdf(開新視窗)
        else:
        
            html = requests.post(url, params)
            html.encoding = html.apparent_encoding
            print(html.text)

            #step5 獲取pdf連結網址
            result = BeautifulSoup(html.text)
            file_name = result.findAll('a')
            fileURL = file_name[0].get('href')
            print(fileURL)

            #step6 存檔
            des_path = "./上市/"+company_id
            if not os.path.isdir(des_path):  #如果資料夾不存在就建立
                os.mkdir(des_path)

            url = 'https://doc.twse.com.tw'+fileURL
            r = requests.get(url)
            pdf = r.content       #響應的二進位制檔案
            with open(des_path+'/'+str(data[0]),'wb') as f:     #二進位制寫入
                f.write(pdf)
        
    print(".....zZzzz.....sleep")
    time.sleep(20)
# Out:
# =================1589=================
# .....zZzzz.....sleep
# ---------99---------
# 查無所需資料
# .....zZzzz.....sleep
# ---------100---------
# 查無所需資料
# .....zZzzz.....sleep
# ---------101---------
# <html><head><title>電子資料查詢作業</title></head><body background='/image/t57sf13.jpg'>
# <center>
# <h2><font color="blue">電子資料查詢作業</font></h2>
# <span id='wait'>請稍候......</span>
# <script>window.wait.style.display='none';</script>
# 電子檔案：<a href='/pdf/2011_1589_20120403F04_20200716_221026.pdf'>2011_1589_20120403F04.pdf</a>
# <p>
# 請點選連結直接開啟或按右鍵另存新檔
# <script>window.focus();</script>
#
# /pdf/2011_1589_20120403F04_20200716_221026.pdf
# .....zZzzz.....sleep
# ---------102---------
# <html><head><title>電子資料查詢作業</title></head><body background='/image/t57sf13.jpg'>
# <center>
# <h2><font color="blue">電子資料查詢作業</font></h2>
# <span id='wait'>請稍候......</span>
# <script>window.wait.style.display='none';</script>
# ...

# %%
print(other)

# %%
des_path = "./"+company_id
if not os.path.isdir(des_path):  #如果資料夾不存在就建立
    os.mkdir(des_path)

# %%
print("---------105---------")
Report_url='https://doc.twse.com.tw/server-java/t57sb01?step=1&colorchg=1&co_id=1215&year=99&mtype=F&'
res=requests.get(Report_url)
soup=BeautifulSoup(res.text)
print(soup)
print("-----0-------")

#step0 驗證有沒有結果
result = soup.find('h4')
if result:
    if result.text == "查無所需資料":
        print(result.text)

#step1 抓表格
Bos_Basic=soup.find('table',{'border':'5'})
print(Bos_Basic)
print("-----1-------")

#step2 抓表格內容
Play_stat_row = Bos_Basic.findAll('tr')
print(Play_stat_row)
print("-----2-------")

#step3 找到年報位置
data=[]
for i in range(0,len(Play_stat_row)):
    Doc = Bos_Basic.findAll('tr')[i].findAll('td')
    for j in range(0,len(Doc)):
        if (Doc[j].find(text="股東會年報")):
            data.append(Doc[j+2].text)
print(data)
# Out:
# ---------105---------
# <html><head><title>電子資料查詢作業</title><meta content="text/html;charset=utf-8" http-equiv="Content-Type"/><link href="/ppp.css" rel="stylesheet" type="text/css"/></head><body>
# <style text="text/css">
# <!--
# 	 TH{color:#000099;font-weight:normal;font-size:10pt}
# -->
# </style>
# <script>
# function readfile(kind,coid,filename)
# {
# 	var f = document.forms[0];
# 	f.step.value = 9;
# 	f.kind.value = kind;
# 	f.co_id.value = coid;
# 	f.filename.value = filename;
# 	f.submit();
# }
# var win = null;
# function readfile2(kind,coid,filename)
# {
# 	var f = document.forms[0];
# 	var today = new Date();
# 	var rand = today.getTime();
# 	if (win==null || win.closed){
# 		win = window.open('','download'+rand);
# 	}
# 	f.target = 'download'+rand;
# 	f.step.value = 9;
# 	f.kind.value = kind;
# 	f.co_id.value = coid;
# 	f.filename.value = filename;
# 	f.submit();
# 	f.target = this;
# }
# </script>
# <center>
# <h2><font color="blue">電子資料查詢作業</font></h2>
# ...

# %%
#step4 分割檔名
firstname = str(data[0])
inform = firstname.split('_')
adyear = inform[0]
company_id = inform[1]
typ = firstname.split('.')

if(typ[1] != "pdf"):
    #step5 傳送表單要求
    url = 'https://doc.twse.com.tw/server-java/t57sb01'
    params = {
        'step': '9',
        'kind': 'F',
        'co_id': company_id,
        'filename': str(data[0]),
    }
    des_path = "./上市/"+company_id
    if not os.path.isdir(des_path):  #如果資料夾不存在就建立
        os.mkdir(des_path)
    r = requests.post(url, params)
    pdf = r.content       #響應的二進位制檔案
    with open(des_path+'/'+str(data[0]),'wb') as f:     #二進位制寫入
        f.write(pdf)

# %%
#step5 獲取pdf連結網址
result = BeautifulSoup(html.text)
file_name = result.findAll('a')
fileURL = file_name[0].get('href')
print(fileURL)

#step6 存擋
des_path = "./上市/"+company_id
if not os.path.isdir(des_path):  #如果資料夾不存在就建立
    os.mkdir(des_path)

url = 'https://doc.twse.com.tw'+fileURL
r = requests.get(url)
pdf = r.content       #響應的二進位制檔案
with open(des_path+'/'+str(data[0])+'.pdf','wb') as f:     #二進位制寫入
    f.write(pdf)
